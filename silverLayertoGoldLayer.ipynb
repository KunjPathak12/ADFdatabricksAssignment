# %%
dfC = spark.read.parquet("/mnt/stagingdata/silverLayer/deltastagingLayer/customerData/part-00000-2dc41dda-a6d6-4601-a664-fa16e6d41539-c000.snappy.parquet")

# %%
dfO = spark.read.parquet("/mnt/stagingdata/silverLayer/deltastagingLayer/orderData/part-00000-2adaa123-8ca6-4b38-b283-4c7fcf0a6ff0-c000.snappy.parquet")

# %%
df.show(5)
dfO.show(5)
# Out:
# +------------+----------+-------+----------+---------+--------+---------+-----+
# |    filename|customerID|country|postalCode|    state|  street|productId|sr_no|
# +------------+----------+-------+----------+---------+--------+---------+-----+
# |orderDetails|  cust5001|  India|    110040|New Delhi|M.G.Road|  prd9001|    1|
# |orderDetails|  cust5001|  India|    110040|New Delhi|M.G.Road|  prd9001|    2|
# |orderDetails|  cust5001|  India|    110040|New Delhi|M.G.Road|  prd9001|    3|
# |orderDetails|  cust5001|  India|    110040|New Delhi|M.G.Road|  prd9001|    4|
# |orderDetails|  cust5001|  India|    110040|New Delhi|M.G.Road|  prd9001|    5|
# +------------+----------+-------+----------+---------+--------+---------+-----+
# only showing top 5 rows
#
# +-----+--------------------+-------+--------+--------+------+----+----+
# |sr_no|           orderDate|orderID|quantity|sequence|grossP|netP|taxP|
# +-----+--------------------+-------+--------+--------+------+----+----+
# ...

# %%
dfJoin = df.join(dfO, df.sr_no==dfO.sr_no,"inner").drop("sr_no")
# Out:
# +------------+----------+-------+----------+---------+--------+---------+--------------------+-------+--------+--------+------+----+----+
# |    filename|customerID|country|postalCode|    state|  street|productId|           orderDate|orderID|quantity|sequence|grossP|netP|taxP|
# +------------+----------+-------+----------+---------+--------+---------+--------------------+-------+--------+--------+------+----+----+
# |orderDetails|  cust5001|  India|    110040|New Delhi|M.G.Road|  prd9001|2021-12-24 00.00....|ord1001|       2|       1|   550| 500|  50|
# |orderDetails|  cust5001|  India|    110040|New Delhi|M.G.Road|  prd9001|2021-12-24 00.00....|ord1001|       2|       1|   550| 500|  60|
# |orderDetails|  cust5001|  India|    110040|New Delhi|M.G.Road|  prd9001|2021-12-24 00.00....|ord1001|       2|       1|   550| 240|  50|
# |orderDetails|  cust5001|  India|    110040|New Delhi|M.G.Road|  prd9001|2021-12-24 00.00....|ord1001|       2|       1|   550| 240|  60|
# ...

# %%
dfJoin.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dfJoin.write.mode("overwrite").format("delta").option("mergeSchema", "true").save("/mnt/stagingdata/goldLayer/cleanData")

# %%
# %fs ls /mnt/stagingdata/goldLayer/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/stagingdata/goldLayer/cleanData/</td><td>cleanData/</td><td>0</td><td>1675165744000</td></tr><tr><td>dbfs:/mnt/stagingdata/goldLayer/cleanedData</td><td>cleanedData</td><td>46367</td><td>1674543679000</td></tr></tbody></table></div>
